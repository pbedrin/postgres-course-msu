# %%
map(str, list(range(1, 10 + 1)))

# %%
from faker import Faker
from random import randint, sample, choice, random, uniform

obj = Faker(['ru_RU', 'en_GB'])
obj.sentence(nb_words=randint(1,3)) # artwork

location = obj.company() # location name
print(location)

loc_types = ['музей', 'частная коллекция', 'строение', 'библиотека', 'вуз', 'склад', 'магазин', 'аукционный дом', 'под открытым небом', 'другое']
loc_type = choice(loc_types)
print(loc_type)

obj.profile(fields=['address', 'mail'])
# Out:
# НПО «Алексеева-Федосеева»
# строение
# {'address': '3 Quinn vista\nNorth Kimberley\nB2A 9TT',
#  'mail': 'carol52@hotmail.com'}

# %%
[obj.name() for i in range(randint(1,2))]
# Out:
# ['Максимов Митофан Феликсович']

# %%
s=''' Сюрреализм', 'направление в искусстве 20 века, сложившееся в 1920-х годах в художественной культуре западного авангардизма. Отличается использованием аллюзий и парадоксальных сочетаний форм'),
Экспрессионизм', 'течение в европейском искусстве эпохи модернизма, получившее наибольшее развитие в первые десятилетия XX века, преимущественно в Германии и Австрии. Экспрессионизм стремится не столько к воспроизведению действительности, сколько к выражению эмоционального состояния автора.'),
Символизм', 'одно из крупнейших течений в искусстве, характеризуемое экспериментаторством, стремлением к новаторству, использованием символики, недосказанности, намёков'),
Краснофигурный стиль', 'приём росписи сосудов в древнегреческой вазописи, при котором фон покрывался черным лаком, а изображения сохраняли цвет глины, обычно красноватый. Детали исполнялись при помощи пера или кисти'),
Реализм', 'направление в искусстве, ставящее целью правдивое воспроизведение действительности в её типичных чертах'),
Ренессанс', 'Ренессанс, или эпоха Возрождения, характеризуется новым пониманием личности человека и его места в окружающем мире, стремлением познать реальность, выразить ее многообразие и красоту через искусство. Основной принцип живописцев Ренессанса – изображать действительность такой, как она есть'),
Тромплёй', 'разновидность изобразительного искусства, способ изображения и совокупность технических приёмов, «создающих иллюзию невозможного, либо напротив — представление доступного, осязаемого, но на самом деле несуществующего»'),
Социалистический реализм', 'главенствующее художественное направление литературы и искусства в СССР и других социалистических странах, представляющее собой эстетическое выражение социалистически осознанной концепции мира и человека, обусловленной эпохой борьбы за установление и созидание социалистического общества'),
Модерн', 'международное художественное движение рубежа XIX—XX веков, ставившее целью выработку нового художественного языка искусства и посредством этого создание нового художественного стиля'),
Неоготика', 'один из неостилей, сложившийся в европейском искусстве XVIII—XIX веков. Имеет несколько фаз развития и различные региональные варианты'),
Деконструктивизм', 'направление в современной архитектуре, основанное на применении в строительной практике концепции деконструкции французского философа Жака Дерриды'),
Малая пластика', 'самый распространенный, особенно популярный вид искусства скульптуры. Мелкая пластика зародилась еще на заре человеческого общества, ее находят при раскопках самых древних поселений.'),
Минималистика', 'стиль в дизайне, характеризующийся лаконичностью выразительных средств, простотой, точностью и ясностью композиции'),
Фентези', 'жанр современного искусства, разновидность фантастики. Произведения жанра фэнтези основываются на мифологических и сказочных мотивах, переосмысленных или переработанных авторами'),
Романтизм', 'идейное и художественное направление в европейской и американской культуре конца XVIII века — первой половины XIX века, характеризуется утверждением самоценности духовно-творческой жизни личности') '''
lst = []
for line in s.splitlines():
	lst.append((line.split('''',''')[0][:]).strip().lower())
print(lst)
# Out:
# ['сюрреализм', 'экспрессионизм', 'символизм', 'краснофигурный стиль', 'реализм', 'ренессанс', 'тромплёй', 'социалистический реализм', 'модерн', 'неоготика', 'деконструктивизм', 'малая пластика', 'минималистика', 'фентези', 'романтизм']
